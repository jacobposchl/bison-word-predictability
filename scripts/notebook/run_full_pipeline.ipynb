# %% [markdown]
# # Code-Switching Predictability Analysis Pipeline

# %% [markdown]
# ## Setup

# %%
# !git clone https://github.com/jacobposchl/bison-word-predictability.git
# !cd bison-word-predictability && pip install -r requirements.txt
# Out:
# Cloning into 'bison-word-predictability'...
# remote: Enumerating objects: 875, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 875 (delta 56), reused 72 (delta 40), pack-reused 775 (from 1)
# Receiving objects: 100% (875/875), 8.06 MiB | 18.17 MiB/s, done.
# Resolving deltas: 100% (500/500), done.
# Collecting pympi-ling>=1.71 (from -r requirements.txt (line 1))
#   Downloading pympi_ling-1.71-py3-none-any.whl.metadata (3.0 kB)
# Collecting pycantonese>=3.0.0 (from -r requirements.txt (line 2))
#   Downloading pycantonese-3.4.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: spacy>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (3.8.11)
# Collecting python-Levenshtein>=0.21.0 (from -r requirements.txt (line 8))
#   Downloading python_levenshtein-0.27.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.66.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: seaborn>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (0.13.2)
# Collecting transformers<4.57,>=4.56.2 (from -r requirements.txt (line 13))
#   Downloading transformers-4.56.2-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece>=0.1.99 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (0.2.1)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (5.29.5)
# Requirement already satisfied: accelerate>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (1.12.0)
# Requirement already satisfied: safetensors>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: torch>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (0.24.0+cu126)
# Requirement already satisfied: torchaudio>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (2.9.0+cu126)
# Requirement already satisfied: scipy==1.16.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 25)) (1.16.3)
# Collecting pytest==9.0.2 (from -r requirements.txt (line 26))
#   Downloading pytest-9.0.2-py3-none-any.whl.metadata (7.6 kB)
# Collecting scikit-learn==1.8.0 (from -r requirements.txt (line 27))
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting bitsandbytes==0.49.1 (from -r requirements.txt (line 30))
#   Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: iniconfig>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->-r requirements.txt (line 26)) (2.3.0)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->-r requirements.txt (line 26)) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->-r requirements.txt (line 26)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->-r requirements.txt (line 26)) (2.19.2)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.8.0->-r requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.8.0->-r requirements.txt (line 27)) (3.6.0)
# Collecting pylangacq<0.17.0,>=0.16.0 (from pycantonese>=3.0.0->-r requirements.txt (line 2))
#   Downloading pylangacq-0.16.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting wordseg==0.0.2 (from pycantonese>=3.0.0->-r requirements.txt (line 2))
#   Downloading wordseg-0.0.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (0.21.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy>=3.7.0->-r requirements.txt (line 7)) (75.2.0)
# Collecting Levenshtein==0.27.3 (from python-Levenshtein>=0.21.0->-r requirements.txt (line 8))
#   Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.3->python-Levenshtein>=0.21.0->-r requirements.txt (line 8))
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<4.57,>=4.56.2->-r requirements.txt (line 13)) (3.20.3)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers<4.57,>=4.56.2->-r requirements.txt (line 13))
#   Downloading huggingface_hub-0.36.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.57,>=4.56.2->-r requirements.txt (line 13)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.57,>=4.56.2->-r requirements.txt (line 13)) (0.22.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.12.0->-r requirements.txt (line 16)) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6.0->-r requirements.txt (line 20)) (3.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<4.57,>=4.56.2->-r requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.7.0->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.7.0->-r requirements.txt (line 7)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.7.0->-r requirements.txt (line 7)) (0.4.2)
# Requirement already satisfied: tabulate<=0.9.0,>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from tabulate[widechars]<=0.9.0,>=0.8.9->pylangacq<0.17.0,>=0.16.0->pycantonese>=3.0.0->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.7.0->-r requirements.txt (line 7)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.7.0->-r requirements.txt (line 7)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.7.0->-r requirements.txt (line 7)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.7.0->-r requirements.txt (line 7)) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.6.0->-r requirements.txt (line 20)) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.7.0->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.7.0->-r requirements.txt (line 7)) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim<1.0.0,>=0.3.0->spacy>=3.7.0->-r requirements.txt (line 7)) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.7.0->-r requirements.txt (line 7)) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.7.0->-r requirements.txt (line 7)) (7.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy>=3.7.0->-r requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy>=3.7.0->-r requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from tabulate[widechars]<=0.9.0,>=0.8.9->pylangacq<0.17.0,>=0.16.0->pycantonese>=3.0.0->-r requirements.txt (line 2)) (0.5.0)
# Downloading pytest-9.0.2-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 37.9 MB/s eta 0:00:00
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 117.8 MB/s eta 0:00:0000:0100:01
# Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 37.5 MB/s eta 0:00:00:00:0100:01
# Downloading pympi_ling-1.71-py3-none-any.whl (25 kB)
# Downloading pycantonese-3.4.0-py3-none-any.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 108.1 MB/s eta 0:00:0000:01
# Downloading wordseg-0.0.2-py3-none-any.whl (9.5 kB)
# Downloading python_levenshtein-0.27.3-py3-none-any.whl (9.5 kB)
# Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 20.7 MB/s eta 0:00:00
# Downloading transformers-4.56.2-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 151.8 MB/s eta 0:00:0000:010:01
# Downloading huggingface_hub-0.36.1-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.3/566.3 kB 51.9 MB/s eta 0:00:00
# Downloading pylangacq-0.16.2-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 8.8 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 117.4 MB/s eta 0:00:00
# Installing collected packages: wordseg, rapidfuzz, pytest, pympi-ling, scikit-learn, pylangacq, Levenshtein, huggingface-hub, python-Levenshtein, pycantonese, transformers, bitsandbytes
#   Attempting uninstall: pytest
#     Found existing installation: pytest 8.4.2
#     Uninstalling pytest-8.4.2:
#       Successfully uninstalled pytest-8.4.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.3.4
#     Uninstalling huggingface_hub-1.3.4:
#       Successfully uninstalled huggingface_hub-1.3.4
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed Levenshtein-0.27.3 bitsandbytes-0.49.1 huggingface-hub-0.36.1 pycantonese-3.4.0 pylangacq-0.16.2 pympi-ling-1.71 pytest-9.0.2 python-Levenshtein-0.27.3 rapidfuzz-3.14.3 scikit-learn-1.8.0 transformers-4.56.2 wordseg-0.0.2

# %%
from google.colab import files
import shutil
from pathlib import Path

# %%
import os
os.chdir('bison-word-predictability')

# %% [markdown]
# Import any files already processed...

# %% [markdown]
# ## 1. Preprocessing

# %%
# !python scripts/preprocess/preprocess.py

# %%
preprocessing_zip = 'preprocessing_results.zip'
if Path('results/preprocessing').exists():
    shutil.make_archive('preprocessing_results', 'zip', 'results/preprocessing')
    files.download(preprocessing_zip)
    print(f"Downloaded {preprocessing_zip}")

# %% [markdown]
# ## 2. Matching

# %%
# !python scripts/matching/matching.py
# Out:
# WARNING: Data path does not exist: ./raw_data
# INFO: Starting POS window matching analysis...
# ERROR: File not found: Translated sentences CSV not found: results/preprocessing/cantonese_translated_WITHOUT_fillers.csv
# ERROR: Please ensure preprocessing has been run first
# ERROR: Run: python scripts/preprocessing/preprocess.py

# %%
matching_zip = 'matching_results.zip'
if Path('results/matching').exists():
    shutil.make_archive('matching_results', 'zip', 'results/matching')
    files.download(matching_zip)
    print(f"Downloaded {matching_zip}")

# %% [markdown]
# ## 3. Surprisal Analysis

# %%
# !python scripts/surprisal/surprisal.py --model masked

# %%
surprisal_zip = 'surprisal_results.zip'
if Path('results/surprisal').exists():
    shutil.make_archive('surprisal_results', 'zip', 'results/surprisal')
    files.download(surprisal_zip)
    print(f"Downloaded {surprisal_zip}")

# %%
# !python scripts/surprisal/surprisal.py --model autoregressive

# %%
surprisal_zip = 'surprisal_results.zip'
if Path('results/surprisal').exists():
    shutil.make_archive('surprisal_results', 'zip', 'results/surprisal')
    files.download(surprisal_zip)
    print(f"Downloaded {surprisal_zip}")

# %% [markdown]
# ## 4. Regression Analysis

# %%
# !python scripts/regression/regression.py --model masked

# %%
regression_zip = 'regression_results.zip'
if Path('results/regression').exists():
    shutil.make_archive('regression_results', 'zip', 'results/regression')
    files.download(regression_zip)
    print(f"Downloaded {regression_zip}")

# %%
# !python scripts/regression/regression.py --model autoregressive

# %%
regression_zip = 'regression_results.zip'
if Path('results/regression').exists():
    shutil.make_archive('regression_results', 'zip', 'results/regression')
    files.download(regression_zip)
    print(f"Downloaded {regression_zip}")
